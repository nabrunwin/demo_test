# %% [markdown]
# # My Jupyter Notebook in IBM Watson

# %% [markdown]
# **Natalie Brunwin** <br>
# Tissue Bank Coordinator

# %% [markdown]
# *I am interested in data science because I like telling stories with data. It is very satisfying to be able to take raw data, clean and analyze it, and then create a report to make that analysis accessible and understandable to all audiences.*

# %% [markdown]
# ### The following code prints "Hello!"

# %%
print("Hello!")
# Out:
# Hello!

# %% [markdown]
# ### Bulleted List
# <br>
# -  First Bullet Point <br>
# -  Second Bullet Point <br>
# -  Third Bullet Point <br>
#
# <br>
#
# ### Table Format
#
# <br>
#
# |One|Two|Three|
# |---|---|-----|
# |cell|cell|cell|
# |Cell|Cell|Cell|
# |cell|cell|cell|
# |Cell|Cell|Cell|
#
# <br>
#
# ### Numbered List
#
# <br>
# 1. Item one <br>
# 2. Item two <br>
# 3. Item three <br>
# 4. Item four <br>
# 5. Item five <br>
